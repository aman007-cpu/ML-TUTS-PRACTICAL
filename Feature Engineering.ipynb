# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('datasetlvl2.pkl','rb'))

# %%
df
#batting team
#bowling team
#city
# current score
# balls left
# wickets left
# current runrate
# last 5 overs
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed     city  \
# 0           2    Australia   0.1    Sri Lanka     0                0      NaN
# 1           2    Australia   0.2    Sri Lanka     0                0      NaN
# 2           2    Australia   0.3    Sri Lanka     1                0      NaN
# 3           2    Australia   0.4    Sri Lanka     2                0      NaN
# 4           2    Australia   0.5    Sri Lanka     0                0      NaN
# ..        ...          ...   ...          ...   ...              ...      ...
# 121       964    Sri Lanka  19.3    Australia     1                0  Colombo
# 122       964    Sri Lanka  19.4    Australia     0                0  Colombo
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva  Colombo
# 124       964    Sri Lanka  19.6    Australia     2                0  Colombo
# 125       964    Sri Lanka  19.7    Australia     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed     city  \
# 0           2    Australia   0.1    Sri Lanka     0                0      NaN
# 1           2    Australia   0.2    Sri Lanka     0                0      NaN
# 2           2    Australia   0.3    Sri Lanka     1                0      NaN
# 3           2    Australia   0.4    Sri Lanka     2                0      NaN
# 4           2    Australia   0.5    Sri Lanka     0                0      NaN
# ..        ...          ...   ...          ...   ...              ...      ...
# 121       964    Sri Lanka  19.3    Australia     1                0  Colombo
# 122       964    Sri Lanka  19.4    Australia     0                0  Colombo
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva  Colombo
# 124       964    Sri Lanka  19.6    Australia     2                0  Colombo
# 125       964    Sri Lanka  19.7    Australia     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# ball                   0
# bowling_team           0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64
# match_id               0
# batting_team           0
# ball                   0
# bowling_team           0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['venue'].str.split().apply(lambda x:x[0])
# Out:
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
#          ...
# 121            R
# 122            R
# 123            R
# 124            R
# 125            R
# Name: venue, Length: 63888, dtype: object
# 0      Melbourne
# 1      Melbourne
# 2      Melbourne
# 3      Melbourne
# 4      Melbourne
#          ...
# 121            R
# 122            R
# 123            R
# 124            R
# 125            R
# Name: venue, Length: 63888, dtype: object

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# ball                0
# bowling_team        0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64
# match_id            0
# batting_team        0
# ball                0
# bowling_team        0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df = df.drop(['venue'],axis='columns')

# %%
df.head()
# Out:
#    match_id batting_team  ball bowling_team  runs player_dismissed       city
# 0         2    Australia   0.1    Sri Lanka     0                0  Melbourne
# 1         2    Australia   0.2    Sri Lanka     0                0  Melbourne
# 2         2    Australia   0.3    Sri Lanka     1                0  Melbourne
# 3         2    Australia   0.4    Sri Lanka     2                0  Melbourne
# 4         2    Australia   0.5    Sri Lanka     0                0  Melbourne
#    match_id batting_team  ball bowling_team  runs player_dismissed       city
# 0         2    Australia   0.1    Sri Lanka     0                0  Melbourne
# 1         2    Australia   0.2    Sri Lanka     0                0  Melbourne
# 2         2    Australia   0.3    Sri Lanka     1                0  Melbourne
# 3         2    Australia   0.4    Sri Lanka     2                0  Melbourne
# 4         2    Australia   0.5    Sri Lanka     0                0  Melbourne

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [50501 rows x 8 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [50501 rows x 8 columns]

# %%
# ball no
df['over'] = df['ball'].apply(lambda x: str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x: str(x).split(".")[1])
df
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [50501 rows x 10 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [50501 rows x 10 columns]

# %%
# balls bowled
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [50501 rows x 11 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [50501 rows x 11 columns]

# %%
# balls left
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]
#      match_id batting_team  ball bowling_team  runs player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                0
# 1           2    Australia   0.2    Sri Lanka     0                0
# 2           2    Australia   0.3    Sri Lanka     1                0
# 3           2    Australia   0.4    Sri Lanka     2                0
# 4           2    Australia   0.5    Sri Lanka     0                0
# ..        ...          ...   ...          ...   ...              ...
# 121       964    Sri Lanka  19.3    Australia     1                0
# 122       964    Sri Lanka  19.4    Australia     0                0
# 123       964    Sri Lanka  19.5    Australia     0      DM de Silva
# 124       964    Sri Lanka  19.6    Australia     2                0
# 125       964    Sri Lanka  19.7    Australia     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]

# %%
#wickets left
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed']  = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left']=  10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [50501 rows x 13 columns]
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [50501 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6/df['balls_bowled'])

# %%
df
# Out:
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [50501 rows x 14 columns]
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [50501 rows x 14 columns]

# %%
groups  = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\amank\AppData\Local\Temp\ipykernel_1120\2125757145.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# C:\Users\amank\AppData\Local\Temp\ipykernel_1120\2125757145.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [50501 rows x 15 columns]
#      match_id batting_team  ball bowling_team  runs  player_dismissed  \
# 0           2    Australia   0.1    Sri Lanka     0                 0
# 1           2    Australia   0.2    Sri Lanka     0                 0
# 2           2    Australia   0.3    Sri Lanka     1                 0
# 3           2    Australia   0.4    Sri Lanka     2                 0
# 4           2    Australia   0.5    Sri Lanka     0                 0
# ..        ...          ...   ...          ...   ...               ...
# 121       964    Sri Lanka  19.3    Australia     1                 8
# 122       964    Sri Lanka  19.4    Australia     0                 8
# 123       964    Sri Lanka  19.5    Australia     0                 9
# 124       964    Sri Lanka  19.6    Australia     2                 9
# 125       964    Sri Lanka  19.7    Australia     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [50501 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 50496             2  6.410256       32.0     128
# 50497             2  6.355932       32.0     128
# 50498             1  6.302521       32.0     128
# 50499             1  6.350000       33.0     128
# 50500             1  6.347107       32.0     128
#
# [50501 rows x 9 columns]
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# 1                10  0.000000        NaN     168
# 2                10  2.000000        NaN     168
# 3                10  4.500000        NaN     168
# 4                10  3.600000        NaN     168
# ...             ...       ...        ...     ...
# 50496             2  6.410256       32.0     128
# 50497             2  6.355932       32.0     128
# 50498             1  6.302521       32.0     128
# 50499             1  6.350000       33.0     128
# 50500             1  6.347107       32.0     128
#
# [50501 rows x 9 columns]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 20339  South Africa  New Zealand      London             63          52
# 14976     Sri Lanka  New Zealand    Auckland             52          65
# 28717         India      England  Manchester            114          41
# 44789         India    Australia    Adelaide            138          25
# 25742         India    Sri Lanka    St Lucia             65          77
# ...             ...          ...         ...            ...         ...
# 8993       Pakistan  New Zealand       Dubai             38          78
# 20767     Sri Lanka     Pakistan      London            142           6
# 12159       England     Pakistan  Manchester            115          40
# 15756       England    Australia   Cape Town            116          27
# 26118      Pakistan    Australia    St Lucia             59          77
#
#        wickets_left       crr  last_five  runs_x
# 20339             7  5.558824       16.0     128
# 14976             5  5.672727       24.0     115
# 28717             6  8.658228       48.0     165
# 44789             8  8.715789       50.0     188
# 25742             9  9.069767       49.0     163
# ...             ...       ...        ...     ...
# 8993              9  5.428571       32.0     166
# 20767             5  7.473684       30.0     150
# 12159             7  8.625000       63.0     131
# 15756             5  7.483871       43.0     135
# 26118            10  8.232558       48.0     191
#
# [38477 rows x 9 columns]
#        batting_team bowling_team        city  current_score  balls_left  \
# 20339  South Africa  New Zealand      London             63          52
# 14976     Sri Lanka  New Zealand    Auckland             52          65
# 28717         India      England  Manchester            114          41
# 44789         India    Australia    Adelaide            138          25
# 25742         India    Sri Lanka    St Lucia             65          77
# ...             ...          ...         ...            ...         ...
# 8993       Pakistan  New Zealand       Dubai             38          78
# 20767     Sri Lanka     Pakistan      London            142           6
# 12159       England     Pakistan  Manchester            115          40
# 15756       England    Australia   Cape Town            116          27
# 26118      Pakistan    Australia    St Lucia             59          77
#
#        wickets_left       crr  last_five  runs_x
# 20339             7  5.558824       16.0     128
# 14976             5  5.672727       24.0     115
# 28717             6  8.658228       48.0     165
# 44789             8  8.715789       50.0     188
# 25742             9  9.069767       49.0     163
# ...             ...       ...        ...     ...
# 8993              9  5.428571       32.0     166
# 20767             5  7.473684       30.0     150
# 12159             7  8.625000       63.0     131
# 15756             5  7.483871       43.0     135
# 26118            10  8.232558       48.0     191
#
# [38477 rows x 9 columns]

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9874183591489014
# 1.6763567899715877
# 0.9874183591489014
# 1.6763567899715877

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']
